# %%
import os
import numpy as np
import polyscope as ps
import polyscope.imgui as psim
from blendshapes import *

# %%
# %load_ext autoreload
# %autoreload 2

# %aimport polyscope
# %aimport polyscope.imgui
# %aimport blendshapes

# %%
manifold_explorer = None
playing = False
manifold_visual = None
save_path = os.path.join(os.pardir, "output", "history.npy")
def draw():
    global playing

    if psim.IsKeyPressed(psim.GetKeyIndex(psim.ImGuiKey_Space)):
        playing = not playing

    if playing:
        V = manifold_explorer.random_step()
        if V is None:
            playing = False
            print("Failed to find a valid direction")
        else:
            manifold_visual.update_vertex_positions(V)
        if psim.Button("Stop"):
            playing = False
    elif psim.Button("Play"):
        playing = True
    
    psim.InputText("", save_path)
    psim.SameLine()
    if psim.Button("Save"):
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        np.save(f"{save_path}", np.array(manifold_explorer.history))
        print(f"Saved history to {save_path}")

# %%
PROJ_PATH = os.path.dirname(os.path.abspath("../"))
BLENDSHAPES_PATH = os.path.join(os.pardir, "data", "Apple blendshapes51 OBJs", "OBJs")
model = load_blendshape_model(BLENDSHAPES_PATH)
# Out:
# 0 mouthFunnel .gltf
# 0 eyeLookInRight .gltf
# 0 mouthRollUpper .obj
# 1 cheekSquintRight .obj
# 2 mouthFrownRight .gltf
# 2 mouthShrugUpper .gltf
# 2 mouthUpperUpLeft .obj
# 3 jawLeft .obj
# 4 mouthPressLeft .gltf
# 4 mouthPucker .obj
# 5 mouthPressRight .obj
# 6 noseSneerRight .gltf
# 6 mouthLowerDownRight .gltf
# 6 eyeLookOutLeft .obj
# 7 mouthPressRight .gltf
# 7 mouthLowerDownLeft .obj
# 8 mouthRollUpper .gltf
# 8 cheekSquintLeft .gltf
# 8 mouthClose .gltf
# 8 browDownLeft .obj
# 9 eyeLookOutLeft .gltf
# 9 mouthRight .obj
# 10 mouthClose .obj
# 11 Neutral .gltf
# 11 mouthUpperUpRight .obj
# 12 eyeLookDownRight .gltf
# 12 noseSneerRight .obj
# 13 mouthSmileRight .gltf
# 13 eyeLookInLeft .gltf
# 13 jawForward .obj
# 14 mouthPressLeft .obj
# 15 browDownLeft .gltf
# 15 jawOpen .obj
# 16 mouthRollLower .obj
# 17 eyeLookUpLeft .obj
# 18 mouthUpperUpLeft .gltf
# 18 mouthStretchRight .gltf
# 18 noseSneerLeft .gltf
# 18 noseSneerLeft .obj
# 19 browDownRight .obj
# 20 eyeLookInRight .obj
# 21 mouthDimpleLeft .obj
# 22 cheekSquintRight .gltf
# 22 Neutral .obj
# 22 eyeLookUpRight .gltf
# 22 mouthLeft .gltf
# 22 eyeBlinkLeft .obj
# 23 eyeLookOutRight .obj
# 24 browOuterUpRight .gltf
# 24 mouthSmileLeft .gltf
# 24 jawOpen .gltf
# 24 jawRight .gltf
# 24 browOuterUpLeft .gltf
# 24 mouthFunnel .obj
# 25 eyeWideLeft .obj
# 26 mouthDimpleLeft .gltf
# 26 mouthPucker .gltf
# 26 browInnerUp .obj
# 27 eyeLookInLeft .obj
# 28 browOuterUpLeft .obj
# 29 mouthDimpleRight .obj
# 30 mouthStretchLeft .obj
# 31 mouthDimpleRight .gltf
# 31 mouthShrugUpper .obj
# 32 mouthSmileRight .obj
# 33 browOuterUpRight .obj
# 34 mouthSmileLeft .obj
# 35 browInnerUp .gltf
# 35 eyeBlinkRight .gltf
# 35 mouthRight .gltf
# 35 eyeLookDownLeft .obj
# 36 mouthUpperUpRight .gltf
# 36 mouthShrugLower .gltf
# 36 eyeSquintRight .obj
# 37 eyeLookDownRight .obj
# 38 cheekPuff .gltf
# 38 eyeBlinkLeft .gltf
# 38 mouthFrownRight .obj
# 39 eyeWideRight .gltf
# 39 eyeWideLeft .gltf
# 39 mouthFrownLeft .obj
# 40 jawRight .obj
# 41 mouthStretchRight .obj
# 42 eyeLookUpLeft .gltf
# 42 eyeLookOutRight .gltf
# 42 mouthLowerDownRight .obj
# 43 mouthRollLower .gltf
# 43 eyeSquintRight .gltf
# 43 jawLeft .gltf
# 43 mouthStretchLeft .gltf
# 43 eyeLookUpRight .obj
# 44 mouthLowerDownLeft .gltf
# 44 eyeSquintLeft .obj
# 45 jawForward .gltf
# 45 cheekPuff .obj
# 46 browDownRight .gltf
# 46 mouthLeft .obj
# 47 eyeSquintLeft .gltf
# 47 eyeLookDownLeft .gltf
# 47 cheekSquintLeft .obj
# 48 eyeWideRight .obj
# 49 mouthShrugLower .obj
# 50 mouthFrownLeft .gltf
# 50 eyeBlinkRight .obj
# Found 51 blendshapes.
# Warning: readOBJ() ignored non-comment line 1:
#   o Neutral
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthRollUpper
# Warning: readOBJ() ignored non-comment line 1:
#   o cheekSquintRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthUpperUpLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o jawLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthPucker
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthPressRight
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookOutLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthLowerDownLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o browDownLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthClose
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthUpperUpRight
# Warning: readOBJ() ignored non-comment line 1:
#   o noseSneerRight
# Warning: readOBJ() ignored non-comment line 1:
#   o jawForward
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthPressLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o jawOpen
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthRollLower
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookUpLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o noseSneerLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o browDownRight
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookInRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthDimpleLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeBlinkLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookOutRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthFunnel
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeWideLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o browInnerUp
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookInLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o browOuterUpLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthDimpleRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthStretchLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthShrugUpper
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthSmileRight
# Warning: readOBJ() ignored non-comment line 1:
#   o browOuterUpRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthSmileLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookDownLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeSquintRight
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookDownRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthFrownRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthFrownLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o jawRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthStretchRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthLowerDownRight
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeLookUpRight
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeSquintLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o cheekPuff
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o cheekSquintLeft
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeWideRight
# Warning: readOBJ() ignored non-comment line 1:
#   o mouthShrugLower
# Warning: readOBJ() ignored non-comment line 1:
#   o eyeBlinkRight

# %%
model.weights[15] = 0.1
model.has_intersections()
# Out:
# False

# %%
ps.set_autocenter_structures(True)
ps.set_program_name("Manifold Explorer")
ps.set_verbosity(0)
ps.set_SSAA_factor(3)
ps.set_max_fps(60)
ps.set_ground_plane_mode("none")
ps.init()
manifold_visual = ps.register_surface_mesh("manifold", model.eval(), model.F, smooth_shade=True, edge_width=0.5, color=(0.8, 0.8, 0.8))
ps.look_at(np.array([0, 0, 0.3]), np.mean(model.V, axis=0))
ps.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/evanpan/Documents/GitHub/ManifoldExploration/src/test_intersections.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/Users/evanpan/Documents/GitHub/ManifoldExploration/src/test_intersections.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> manifold_visual = ps.register_surface_mesh("manifold", model.eval(), model.F, smooth_shade=True, edge_width=0.5, color=(0.8, 0.8, 0.8))
#       <a href='vscode-notebook-cell:/Users/evanpan/Documents/GitHub/ManifoldExploration/src/test_intersections.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> ps.look_at(np.array([0, 0, 0.3]), np.mean(model.V, axis=0))
# ---> <a href='vscode-notebook-cell:/Users/evanpan/Documents/GitHub/ManifoldExploration/src/test_intersections.ipynb#W5sZmlsZQ%3D%3D?line=9'>10</a> ps.show()
#
# File ~/opt/anaconda3/envs/mediapipe/lib/python3.10/site-packages/polyscope/core.py:24, in show(forFrames)
#      22 """Show the Polyscope GUI (blocks until UI is exited)"""
#      23 if forFrames is None:
# ---> 24     psb.show()
#      25 else:
#      26     psb.show(forFrames)
#
# KeyboardInterrupt:
